# %%
dfr = spark.read
df = dfr.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv"
             ,header = True
             ,inferSchema= True)
print(type(df))
df.printSchema()
display(df)

# %% [markdown]
# ## Create data Frame from Delimiter

# %%
df = spark.read.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.dat"
                   ,header = True
                   ,inferSchema= True
                   ,sep = "|").display()

# %% [markdown]
# ##Create DataFrame From JSON

# %%
df = spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.json").display()

# %%
df = spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_002.json"
                     ,multiLine=True).display()

# %%
df = spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_003.json"
                     ,multiLine=True).display()

# %%
df = spark.read.json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_004.json"
                     ,multiLine=True).display()

# %% [markdown]
# ## Create DataFrame from parquet

# %%
spark.read.parquet("/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users.parquet").display()

# %% [markdown]
# ## Creating DataFrame from cloud Storage

# %% [markdown]
# ## Custom Schema

# %%
from pyspark.sql.types import *

CUSTOM_SCHEMA = StructType([
    StructField("id", IntegerType(), True),
    StructField("age", IntegerType(), True),
    StructField("gen", StringType(), True),
    StructField("desig", StringType(), True),
    StructField("salary", IntegerType(), True),
])

spark.read.csv(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv"
             ,header = True
             ,schema= CUSTOM_SCHEMA).display()

# %% [markdown]
# ##handling bad records

# %% [markdown]
# ##Permissive (Defualt) stores corrupt in a column

# %%
spark.read.option("columnNameOfCorruptRecord","bad_record").json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
                mode="PERMISSIVE"
                ).display()

# %% [markdown]
# ##DROPMALFORMED (Drops corrupt records and read non corrupt record)

# %%
spark.read.option("columnNameOfCorruptRecord","bad_record").json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
                mode="DROPMALFORMED"
                ).display()

# %% [markdown]
# ##FAILFAST (Does not read file even one record is corrupt)

# %%
spark.read.option("columnNameOfCorruptRecord","bad_record").json(path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/access_logs.json",
                mode="FAILFAST"
                ).display()

# %%
df = spark.read.csv(
path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
header=True,
inferSchema=True
 
)
 
df.write.format("parquet").save("/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_parquet new")

# %%
df = spark.read.csv(
path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
header=True,
inferSchema=True
 
)
 
df.write.format("json").save("/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_jason_new")

# %% [markdown]
# ## Output Modes

# %%
import pyarrow.parquet as pq 

user_table = pq.read_table("/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_parquet new/part-00000-tid-3765455400012049559-7b16e66d-c9f5-4d0a-9627-075ec99f6ca8-128-1.c000.snappy.parquet")

user_table.to_pandas().head()

# %% [markdown]
# ## OVERWITE MODE

# %%
df = spark.read.csv(
path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
header=True,
inferSchema=True
 
)
 
df.write.format("json").save("/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_jason_new"
                             ,mode="overwrite")

# %%
df = spark.read.csv(
path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
header=True,
inferSchema=True
 
)
 
df.write.format("json").save("/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_jason_new"
                             ,mode="append")

# %%
df = spark.read.csv(
path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
header=True,
inferSchema=True
 
)
 
df.write.format("json").save("/Volumes/quickstart_catalog/quickstart_schema/sandbox/output_jason_new"
                             ,mode="ignore")

# %%
spark.read.csv(
path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/sample_dataset/users_001.csv",
header=True,
inferSchema=True
 
).display()
