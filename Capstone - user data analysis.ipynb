# %%
df = spark.read.csv(
    path="/Volumes/quickstart_catalog/quickstart_schema/sandbox/dataset/user_dataset/users_001.csv",
    header=True,
    inferSchema=True,
)

df.display()

# %%
from pyspark.sql.functions import col
def find_distinct_country(df):
    df.select(col("country")).distinct()

# %%
from pyspark.sql.functions import col
df.select(col("country")).distinct().display()
a=df.select(col("country")).distinct().collect()[1][0]
print(a)
